# %%
from redelex import datasets as ctudatasets
from redelex import tasks as ctutasks

# %%
dataset = ctudatasets.Seznam()
print(dataset)
# Out:
# Seznam(remote_url=mariadb+pymysql://guest:ctu-relational@relational.fel.cvut.cz:3306/Seznam)

# %%
tasks = ctutasks
print(tasks)
# Out:
# <module 'redelex.tasks' from '/home/burak/.local/share/mamba/envs/gt/lib/python3.12/site-packages/redelex/tasks/__init__.py'>
